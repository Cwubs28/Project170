# %%
# !pip install lyricsgenius

# %%
import lyricsgenius

# with open("client_token", "r") as file:

access_token = "lWqMgyr71Bnm6QLCd0_J8vCCmiIvbSfC9xhfBDZ4jFGtT3PJN1VLplK65vkv3OqA"

genius = lyricsgenius.Genius(access_token)




artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
